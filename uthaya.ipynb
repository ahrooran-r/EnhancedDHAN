# %%
# !git clone https://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:x-oauth-basic@github.com/arulUthaya/GHAN.git
# Out:
# Cloning into 'GHAN'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 45 (delta 13), reused 38 (delta 8), pack-reused 0
# Unpacking objects: 100% (45/45), done.

# %%
# %cd /content/GHAN/
# Out:
# /content/GHAN

# %%
# !python train_sr.py --data_dir "./dataset/train" --use_da 0
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !ls
# Out:
# __pycache__  ST_CGAN.py

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/dataset-20211201T175940Z-001.zip" "/content/GHAN"

# %%
# !unzip "/content/GHAN/dataset-20211201T175940Z-001.zip"  -d "/content/GHAN/"
# Out:
# Archive:  /content/GHAN/dataset-20211201T175940Z-001.zip
#   inflating: /content/GHAN/dataset/test/test_B/175.jpg
#   inflating: /content/GHAN/dataset/test/test_B/174.jpg
#   inflating: /content/GHAN/dataset/test/test_B/170.jpg
#   inflating: /content/GHAN/dataset/test/test_B/168.jpg
#   inflating: /content/GHAN/dataset/test/test_B/169.jpg
#   inflating: /content/GHAN/dataset/test/test_B/178.jpg
#   inflating: /content/GHAN/dataset/test/test_B/167.jpg
#   inflating: /content/GHAN/dataset/test/test_B/180.jpg
#   inflating: /content/GHAN/dataset/test/test_B/177.jpg
#   inflating: /content/GHAN/dataset/test/test_B/179.jpg
#   inflating: /content/GHAN/dataset/test/test_B/171.jpg
#   inflating: /content/GHAN/dataset/test/test_B/172.jpg
#   inflating: /content/GHAN/dataset/test/test_B/165.jpg
#   inflating: /content/GHAN/dataset/test/test_B/173.jpg
#   inflating: /content/GHAN/dataset/test/test_B/164.jpg
#   inflating: /content/GHAN/dataset/test/test_B/181.jpg
# ...

# %%
# %cd /content/drive/MyDrive/
# !pip install unrar
# !unrar x ISTD_Dataset.rar -d "/content/GHAN/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !pip install tensorflow==1.13.2
# Out:
# ...
#      |████████████████████████████████| 92.7 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 367 kB 34.6 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 41.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.8 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !gdown https://drive.google.com/uc?id=1rEIWWLwEpbZGPyFUc9jSIQr78ZeQy5eZ
# !unzip srdplus-pretrained.zip && rm srdplus-pretrained.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1rEIWWLwEpbZGPyFUc9jSIQr78ZeQy5eZ
# To: /content/GHAN/Models/srdplus-pretrained.zip
# 100% 320M/320M [00:03<00:00, 93.2MB/s]
# Archive:  srdplus-pretrained.zip
#    creating: srdplus-pretrained/
#   inflating: srdplus-pretrained/checkpoint
#   inflating: srdplus-pretrained/model_best.ckpt.data-00000-of-00001
#   inflating: srdplus-pretrained/model_best.ckpt.index
#   inflating: srdplus-pretrained/model_best.ckpt.meta

# %%
# !gdown https://drive.google.com/uc?id=1r6QD7lEM6UTMbnoxEQqTsK0k0B8XziC1
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1r6QD7lEM6UTMbnoxEQqTsK0k0B8XziC1
# To: /content/GHAN/Models/imagenet-vgg-verydeep-19.mat
# 100% 535M/535M [00:06<00:00, 85.3MB/s]
